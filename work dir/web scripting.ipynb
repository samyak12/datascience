# %%
import requests

# %%
res= requests.get('http://mfd.gov.np/')

# %%
res
# Out:
# <Response [200]>

# %%
res.headers
# Out:
# {'Date': 'Wed, 30 Aug 2017 01:56:13 GMT', 'Server': 'Apache/2.2.15 (CentOS)', 'X-Powered-By': 'PHP/5.3.3', 'Set-Cookie': 'PHPSESSID=juuhisjhvuumepatcf0b20dde6; path=/', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Pragma': 'no-cache', 'Connection': 'close', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=utf-8'}

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<title>Meteorological Forecasting Division</title>\n\n\t<meta name="viewport"\n\tcontent="width=device-width, initial-scale=1.0, user-scalable=no">\n  <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>\n\t<link href="/mfd.gov.np/_bootstrap/css/bootstrap.css"\n\trel="stylesheet">\n\t<link href="/mfd.gov.np/_stylesheets/mfd.css" rel="stylesheet">\n\t<link rel="icon"\n      type="image/png" \n      href="/mfd.gov.np/_req/favicon.png">\n\t\t\t\t\t\t\n\t<!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->\n    <!-- WARNING: Respond.js doesn\'t work if you view the page via file:// -->\n    <!--[if lt IE 9]>\n\t<script src="/mfd.gov.np/_js/html5shiv.js"></script>\n\t<script src="/mfd.gov.np/_js/respond.min.js"></script>\n\n\n\t<![endif]-->\n<style>\n@media (min-width: 768px){\n\t.navbar-static-top {\n\t\tborder-radius: 6px;\n\t}\n}\n</style>\n</head>\n\n<body>\n<div class="site-header">\n\t<div class="container">\n\t <div class="col-sm-4">\n\t\t<img width="64px" src="/mfd.gov.np/_req/logo.png" />\n\t\t<h2 style="margin-bottom: 5px">Government of Nepal</h2>\n\t\t<h2>Department of Hydrology and Meteorology</h2>\n\t\t<h1>Meteorological Forecasting Division</h1>\n\t </div>\n\t \n\t <div class="col-sm-8" style="padding-top:10px;">\n\t \n\t \n\t \t<div class="navbar navbar-inverse navbar-static-top" role="navigation">\n\t\t\t<div class="navbar-header">\n\t\t\t\t<button type="button" class="navbar-toggle" data-toggle="collapse"\n\t\t\t\t\t\tdata-target=".navbar-collapse">\n\t\t\t\t\t<span class="sr-only">Toggle navigation</span> <span\n\t\t\t\t\t\t\tclass="icon-bar"></span> <span class="icon-bar"></span> <span\n\t\t\t\t\t\t\tclass="icon-bar"></span>\n\t\t\t\t</button>\n\t\t\t\t<!-- <a class="navbar-brand" href="#">MFD</a> -->\n\t\t\t</div>\n\t\t\t<div class="navbar-collapse collapse">\n\t\t\t\t<ul class="nav navbar-nav">\n\t\t\t\t\t<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>\n\t\t\t\t</ul>\n\t\t\t</div>\n\t\t</div>\n\t \n\t </div>\n\t \n\t</div>\n\n</div>\n\t\n<DIV class="carousel slide" id="mainCarousel" data-ride="carousel"><ol class="carousel-indicators"><li class="active" data-target="#mainCarousel" data-slide-to="0" data-ride="carousel"></li><li data-target="#mainCarousel" data-slide-to="1" data-ride="carousel"></li><li data-target="#mainCarousel" data-slide-to="2" data-ride="carousel"></li><li data-target="#mainCarousel" data-slide-to="3" data-ride="carousel"></li><li data-target="#mainCarousel" data-slide-to="4" data-ride="carousel"></li></ol><div class="carousel-inner"><div class="item active"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/e0653490535cdd82fe487260b6c6f6f5.png"></img><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=22"><h1>Dipayal</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png" /><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>24 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:58 am</strong>, Sunset: <strong>6:46 pm</strong></div><div><a href="city?id=22">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/f927b55f77a8cf4ad32cdd88d3b6feae.jpg"></img><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=24"><h1>Birendranagar</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png" /><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>25 °C</strong></div><div><label>Humidity: </label><strong>95 % ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(res.text,'html5lib')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# <title>Meteorological Forecasting Division</title>
#
# 	<meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# 	<link href="/mfd.gov.np/_bootstrap/css/bootstrap.css" rel="stylesheet"/>
# 	<link href="/mfd.gov.np/_stylesheets/mfd.css" rel="stylesheet"/>
# 	<link href="/mfd.gov.np/_req/favicon.png" rel="icon" type="image/png"/>
#
# 	<!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#     <!--[if lt IE 9]>
# 	<script src="/mfd.gov.np/_js/html5shiv.js"></script>
# 	<script src="/mfd.gov.np/_js/respond.min.js"></script>
#
#
# 	<![endif]-->
# <style>
# @media (min-width: 768px){
# 	.navbar-static-top {
# 		border-radius: 6px;
# 	}
# }
# </style>
# </head>
#
# <body>
# <div class="site-header">
# 	<div class="container">
# 	 <div class="col-sm-4">
# 		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
# 		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
# 		<h2>Department of Hydrology and Meteorology</h2>
# 		<h1>Meteorological Forecasting Division</h1>
# 	 </div>
#
# 	 <div class="col-sm-8" style="padding-top:10px;">
#
#
# 	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
# 			<div class="navbar-header">
# 				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# 					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
# 				</button>
# 				<!-- <a class="navbar-brand" href="#">MFD</a> -->
# 			</div>
# 			<div class="navbar-collapse collapse">
# 				<ul class="nav navbar-nav">
# 					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
# 				</ul>
# 			</div>
# 		</div>
#
# 	 </div>
#
# 	</div>
#
# </div>
#
# <div class="carousel slide" data-ride="carousel" id="mainCarousel"><ol class="carousel-indicators"><li class="active" data-ride="carousel" data-slide-to="0" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="1" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="2" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="3" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="4" data-target="#mainCarousel"></li></ol><div class="carousel-inner"><div class="item active"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/e0653490535cdd82fe487260b6c6f6f5.png"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=22"><h1>Dipayal</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>24 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:58 am</strong>, Sunset: <strong>6:46 pm</strong></div><div><a href="city?id=22">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/f927b55f77a8cf4ad32cdd88d3b6feae.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=24"><h1>Birendranagar</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>25 °C</strong></div><div><label>Humidity: </label><strong>95 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:56 am</strong>, Sunset: <strong>6:43 pm</strong></div><div><a href="city?id=24">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/0f8207ee86bf76097055c962df157415.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=28"><h1>Pokhara</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/19-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>22.8 °C</strong></div><div><label>Humidity: </label><strong>96 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:47 am</strong>, Sunset: <strong>6:33 pm</strong></div><div><a href="city?id=28">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/bf0ccd1466119e6785c7bc576b88851e.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=31"><h1>Kathmandu</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>20 °C</strong></div><div><label>Humidity: </label><strong>94 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:42 am</strong>, Sunset: <strong>6:27 pm</strong></div><div><a href="city?id=31">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/8e9309b9514a49e5b0d09ab5139fe108.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=33"><h1>Dhankuta</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/3-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>21 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:35 am</strong>, Sunset: <strong>6:19 pm</strong></div><div><a href="city?id=33">Read More...</a></div></div> ...
# 	<div class="container">
# 		<div class="row">
# 			<div class="col-sm-6">
# 				<h3>Contact Us</h3>
# 				<h4>Meteorological Forecasting Division</h4>
# 				<p>Gauchar, Tribhuvan International Airport<br/>
# 					Kathmandu, Nepal<br/>
# 					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
# 					+977 1 4486869<br/>
# 					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
# 					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
# 				</p>
# 				<p><b>Please dial and listen to us for notice board service</b>
# 				</p><dl class="footer-number-list dl-horizontal">
# 					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
# 					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
# 					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
# 					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
# 				</dl>
# 			</div>
# 			<div class="col-sm-6">
# 				<h3>Links</h3>
# 				<h4>
# 					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
# 						Meteorology</a>
# 				</h4>
#
# 				<h4>
# 					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
# 				</h4>
# 				<h4>
# 					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
# 				</h4>
# 			</div>
# 		</div>
# 	</div>
# <iframe src="http://dhm.gov.np/commonfooter.php" style="width:100%; border:none"></iframe>
#
#
# </footer>
# <div class="copyright-line">
# 	<div class="container">
#
# 		<div class="row">
#
# 			<div class="col-sm-6">
#
# 				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
# 			</div>
#
# 			<div class="col-sm-6">
#
# 				<p><small>
#
# 						Designed and developed by <a href="http://www.rts.com.np">Real
#
# 							Time Solutions Pvt. Ltd.</a></small>
# 				</p>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <script src="/mfd.gov.np/_jquery/jquery-1.11.0.min.js"></script>
# <script src="/mfd.gov.np/_bootstrap/js/bootstrap.min.js"></script>
#
#
#
# <script src="/mfd.gov.np/_js/highstock.js"></script>
#
# <script> $('li').tooltip(); </script>
#
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-48154100-1', 'www.mfd.gov.np');
# 	ga('send', 'pageview');
#
# </script>
#
#
# </body></html>

# %%
soup.find('div')
# Out:
# <div class="site-header">
# 	<div class="container">
# 	 <div class="col-sm-4">
# 		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
# 		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
# 		<h2>Department of Hydrology and Meteorology</h2>
# 		<h1>Meteorological Forecasting Division</h1>
# 	 </div>
#
# 	 <div class="col-sm-8" style="padding-top:10px;">
#
#
# 	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
# 			<div class="navbar-header">
# 				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# 					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
# 				</button>
# 				<!-- <a class="navbar-brand" href="#">MFD</a> -->
# 			</div>
# 			<div class="navbar-collapse collapse">
# 				<ul class="nav navbar-nav">
# 					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
# 				</ul>
# 			</div>
# 		</div>
#
# 	 </div>
#
# 	</div>
#
# </div>

# %%
soup.find_all()
# Out:
# [<html><head>
#  <title>Meteorological Forecasting Division</title>
#
#  	<meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#    <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#  	<link href="/mfd.gov.np/_bootstrap/css/bootstrap.css" rel="stylesheet"/>
#  	<link href="/mfd.gov.np/_stylesheets/mfd.css" rel="stylesheet"/>
#  	<link href="/mfd.gov.np/_req/favicon.png" rel="icon" type="image/png"/>
#
#  	<!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
#      <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#      <!--[if lt IE 9]>
#  	<script src="/mfd.gov.np/_js/html5shiv.js"></script>
#  	<script src="/mfd.gov.np/_js/respond.min.js"></script>
#
#
#  	<![endif]-->
#  <style>
#  @media (min-width: 768px){
#  	.navbar-static-top {
#  		border-radius: 6px;
#  	}
#  }
#  </style>
#  </head>
#
#  <body>
#  <div class="site-header">
#  	<div class="container">
#  	 <div class="col-sm-4">
#  		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
#  		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
#  		<h2>Department of Hydrology and Meteorology</h2>
#  		<h1>Meteorological Forecasting Division</h1>
#  	 </div>
#
#  	 <div class="col-sm-8" style="padding-top:10px;">
#
#
#  	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
#  			<div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>
#  			<div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>
#  		</div>
#
#  	 </div>
#
#  	</div>
#
#  </div>
#
#  <div class="carousel slide" data-ride="carousel" id="mainCarousel"><ol class="carousel-indicators"><li class="active" data-ride="carousel" data-slide-to="0" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="1" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="2" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="3" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="4" data-target="#mainCarousel"></li></ol><div class="carousel-inner"><div class="item active"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/e0653490535cdd82fe487260b6c6f6f5.png"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=22"><h1>Dipayal</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>24 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:58 am</strong>, Sunset: <strong>6:46 pm</strong></div><div><a href="city?id=22">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/f927b55f77a8cf4ad32cdd88d3b6feae.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=24"><h1>Birendranagar</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>25 °C</strong></div><div><label>Humidity: </label><strong>95 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:56 am</strong>, Sunset: <strong>6:43 pm</strong></div><div><a href="city?id=24">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/0f8207ee86bf76097055c962df157415.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=28"><h1>Pokhara</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/19-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>22.8 °C</strong></div><div><label>Humidity: </label><strong>96 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:47 am</strong>, Sunset: <strong>6:33 pm</strong></div><div><a href="city?id=28">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/bf0ccd1466119e6785c7bc576b88851e.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=31"><h1>Kathmandu</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>20 °C</strong></div><div><label>Humidity: </label><strong>94 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:42 am</strong>, Sunset: <strong>6:27 pm</strong></div><div><a href="city?id=31">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/8e9309b9514a49e5b0d09ab5139fe108.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=33"><h1>Dhankuta</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/3-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>21 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:35 am</strong>, Sunset: <strong>6:19 pm</strong></div><div><a href="city?id=33">Read More...</a></div></div ...
#  	<div class="container">
#  		<div class="row">
#  			<div class="col-sm-6">
#  				<h3>Contact Us</h3>
#  				<h4>Meteorological Forecasting Division</h4>
#  				<p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>
#  				<p><b>Please dial and listen to us for notice board service</b>
#  				</p><dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>
#  			</div>
#  			<div class="col-sm-6">
#  				<h3>Links</h3>
#  				<h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>
#
#  				<h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>
#  				<h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>
#  			</div>
#  		</div>
#  	</div>
#  <iframe src="http://dhm.gov.np/commonfooter.php" style="width:100%; border:none"></iframe>
#
#
#  </footer>
#  <div class="copyright-line">
#  	<div class="container">
#
#  		<div class="row">
#
#  			<div class="col-sm-6">
#
#  				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
#  			</div>
#
#  			<div class="col-sm-6">
#
#  				<p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>
#  			</div>
#  		</div>
#  	</div>
#  </div>
#  <script src="/mfd.gov.np/_jquery/jquery-1.11.0.min.js"></script>
#  <script src="/mfd.gov.np/_bootstrap/js/bootstrap.min.js"></script>
#
#
#
#  <script src="/mfd.gov.np/_js/highstock.js"></script>
#
#  <script> $('li').tooltip(); </script>
#
#  <script>
#  	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#  	ga('create', 'UA-48154100-1', 'www.mfd.gov.np');
#  	ga('send', 'pageview');
#
#  </script>
#
#
#  </body></html>, <head>
#  <title>Meteorological Forecasting Division</title>
#
#  	<meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#    <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#  	<link href="/mfd.gov.np/_bootstrap/css/bootstrap.css" rel="stylesheet"/>
#  	<link href="/mfd.gov.np/_stylesheets/mfd.css" rel="stylesheet"/>
#  	<link href="/mfd.gov.np/_req/favicon.png" rel="icon" type="image/png"/>
#
#  	<!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
#      <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#      <!--[if lt IE 9]>
#  	<script src="/mfd.gov.np/_js/html5shiv.js"></script>
#  	<script src="/mfd.gov.np/_js/respond.min.js"></script>
#
#
#  	<![endif]-->
#  <style>
#  @media (min-width: 768px){
#  	.navbar-static-top {
#  		border-radius: 6px;
#  	}
#  }
#  </style>
#  </head>, <title>Meteorological Forecasting Division</title>, <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>, <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>, <link href="/mfd.gov.np/_bootstrap/css/bootstrap.css" rel="stylesheet"/>, <link href="/mfd.gov.np/_stylesheets/mfd.css" rel="stylesheet"/>, <link href="/mfd.gov.np/_req/favicon.png" rel="icon" type="image/png"/>, <style>
#  @media (min-width: 768px){
#  	.navbar-static-top {
#  		border-radius: 6px;
#  	}
#  }
#  </style>, <body>
#  <div class="site-header">
#  	<div class="container">
#  	 <div class="col-sm-4">
#  		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
#  		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
#  		<h2>Department of Hydrology and Meteorology</h2>
#  		<h1>Meteorological Forecasting Division</h1>
#  	 </div>
#
#  	 <div class="col-sm-8" style="padding-top:10px;">
#
#
#  	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
#  			<div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>
#  			<div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>
#  		</div>
#
#  	 </div>
#
#  	</div>
#
#  </div>
#
#  <div class="carousel slide" data-ride="carousel" id="mainCarousel"><ol class="carousel-indicators"><li class="active" data-ride="carousel" data-slide-to="0" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="1" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="2" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="3" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="4" data-target="#mainCarousel"></li></ol><div class="carousel-inner"><div class="item active"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/e0653490535cdd82fe487260b6c6f6f5.png"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=22"><h1>Dipayal</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>24 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:58 am</strong>, Sunset: <strong>6:46 pm</strong></div><div><a href="city?id=22">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/f927b55f77a8cf4ad32cdd88d3b6feae.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=24"><h1>Birendranagar</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>25 °C</strong></div><div><label>Humidity: </label><strong>95 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:56 am</strong>, Sunset: <strong>6:43 pm</strong></div><div><a href="city?id=24">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/0f8207ee86bf76097055c962df157415.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=28"><h1>Pokhara</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/19-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>22.8 °C</strong></div><div><label>Humidity: </label><strong>96 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:47 am</strong>, Sunset: <strong>6:33 pm</strong></div><div><a href="city?id=28">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/bf0ccd1466119e6785c7bc576b88851e.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=31"><h1>Kathmandu</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>20 °C</strong></div><div><label>Humidity: </label><strong>94 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:42 am</strong>, Sunset: <strong>6:27 pm</strong></div><div><a href="city?id=31">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/8e9309b9514a49e5b0d09ab5139fe108.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=33"><h1>Dhankuta</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/3-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>21 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:35 am</strong>, Sunset: <strong>6:19 pm</strong></div><div><a href="city?id=33">Read More...</a></div></div ...
#  	<div class="container">
#  		<div class="row">
#  			<div class="col-sm-6">
#  				<h3>Contact Us</h3>
#  				<h4>Meteorological Forecasting Division</h4>
#  				<p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>
#  				<p><b>Please dial and listen to us for notice board service</b>
#  				</p><dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>
#  			</div>
#  			<div class="col-sm-6">
#  				<h3>Links</h3>
#  				<h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>
#
#  				<h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>
#  				<h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>
#  			</div>
#  		</div>
#  	</div>
#  <iframe src="http://dhm.gov.np/commonfooter.php" style="width:100%; border:none"></iframe>
#
#
#  </footer>
#  <div class="copyright-line">
#  	<div class="container">
#
#  		<div class="row">
#
#  			<div class="col-sm-6">
#
#  				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
#  			</div>
#
#  			<div class="col-sm-6">
#
#  				<p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>
#  			</div>
#  		</div>
#  	</div>
#  </div>
#  <script src="/mfd.gov.np/_jquery/jquery-1.11.0.min.js"></script>
#  <script src="/mfd.gov.np/_bootstrap/js/bootstrap.min.js"></script>
#
#
#
#  <script src="/mfd.gov.np/_js/highstock.js"></script>
#
#  <script> $('li').tooltip(); </script>
#
#  <script>
#  	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#  	ga('create', 'UA-48154100-1', 'www.mfd.gov.np');
#  	ga('send', 'pageview');
#
#  </script>
#
#
#  </body>, <div class="site-header">
#  	<div class="container">
#  	 <div class="col-sm-4">
#  		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
#  		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
#  		<h2>Department of Hydrology and Meteorology</h2>
#  		<h1>Meteorological Forecasting Division</h1>
#  	 </div>
#
#  	 <div class="col-sm-8" style="padding-top:10px;">
#
#
#  	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
#  			<div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>
#  			<div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>
#  		</div>
#
#  	 </div>
#
#  	</div>
#
#  </div>, <div class="container">
#  	 <div class="col-sm-4">
#  		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
#  		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
#  		<h2>Department of Hydrology and Meteorology</h2>
#  		<h1>Meteorological Forecasting Division</h1>
#  	 </div>
#
#  	 <div class="col-sm-8" style="padding-top:10px;">
#
#
#  	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
#  			<div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>
#  			<div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>
#  		</div>
#
#  	 </div>
#
#  	</div>, <div class="col-sm-4">
#  		<img src="/mfd.gov.np/_req/logo.png" width="64px"/>
#  		<h2 style="margin-bottom: 5px">Government of Nepal</h2>
#  		<h2>Department of Hydrology and Meteorology</h2>
#  		<h1>Meteorological Forecasting Division</h1>
#  	 </div>, <img src="/mfd.gov.np/_req/logo.png" width="64px"/>, <h2 style="margin-bottom: 5px">Government of Nepal</h2>, <h2>Department of Hydrology and Meteorology</h2>, <h1>Meteorological Forecasting Division</h1>, <div class="col-sm-8" style="padding-top:10px;">
#
#
#  	 	<div class="navbar navbar-inverse navbar-static-top" role="navigation">
#  			<div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>
#  			<div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>
#  		</div>
#
#  	 </div>, <div class="navbar navbar-inverse navbar-static-top" role="navigation">
#  			<div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>
#  			<div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>
#  		</div>, <div class="navbar-header">
#  				<button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>
#  				<!-- <a class="navbar-brand" href="#">MFD</a> -->
#  			</div>, <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  					<span class="sr-only">Toggle navigation</span> <span class="icon-bar"></span> <span class="icon-bar"></span> <span class="icon-bar"></span>
#  				</button>, <span class="sr-only">Toggle navigation</span>, <span class="icon-bar"></span>, <span class="icon-bar"></span>, <span class="icon-bar"></span>, <div class="navbar-collapse collapse">
#  				<ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>
#  			</div>, <ul class="nav navbar-nav">
#  					<li><a href="/">Home</a></li><li><a href="/weather/">Weather</a></li><li><a href="/nwp/">NWP</a></li><li><a href="/satellite/">Satellite</a></li><li><a href="/mountaineering/">Mountaineering</a></li><li><a href="/report/">Archives</a></li>
#  				</ul>, <li><a href="/">Home</a></li>, <a href="/">Home</a>, <li><a href="/weather/">Weather</a></li>, <a href="/weather/">Weather</a>, <li><a href="/nwp/">NWP</a></li>, <a href="/nwp/">NWP</a>, <li><a href="/satellite/">Satellite</a></li>, <a href="/satellite/">Satellite</a>, <li><a href="/mountaineering/">Mountaineering</a></li>, <a href="/mountaineering/">Mountaineering</a>, <li><a href="/report/">Archives</a></li>, <a href="/report/">Archives</a>, <div class="carousel slide" data-ride="carousel" id="mainCarousel"><ol class="carousel-indicators"><li class="active" data-ride="carousel" data-slide-to="0" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="1" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="2" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="3" data-target="#mainCarousel"></li><li data-ride="carousel" data-slide-to="4" data-target="#mainCarousel"></li></ol><div class="carousel-inner"><div class="item active"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/e0653490535cdd82fe487260b6c6f6f5.png"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=22"><h1>Dipayal</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>24 °C</strong></div><div><label>Humidity: </label><strong>98 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:58 am</strong>, Sunset: <strong>6:46 pm</strong></div><div><a href="city?id=22">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/f927b55f77a8cf4ad32cdd88d3b6feae.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=24"><h1>Birendranagar</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>25 °C</strong></div><div><label>Humidity: </label><strong>95 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:56 am</strong>, Sunset: <strong>6:43 pm</strong></div><div><a href="city?id=24">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/0f8207ee86bf76097055c962df157415.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=28"><h1>Pokhara</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/19-moon-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>22.8 °C</strong></div><div><label>Humidity: </label><strong>96 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:47 am</strong>, Sunset: <strong>6:33 pm</strong></div><div><a href="city?id=28">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/bf0ccd1466119e6785c7bc576b88851e.jpg"/><div class="container"><div class="carousel-caption"><div class="station-highlight"><a href="city?id=31"><h1>Kathmandu</h1></a><div class="WeatherNow"><img src="/mfd.gov.np/_req/weather_icons/4-sun-64.png"/><div>At <strong>5:45 am</strong>,</div><div><label>Temperature: </label><strong>20 °C</strong></div><div><label>Humidity: </label><strong>94 %</strong></div><hr/></div><div><div class="SunInfo">Sunrise: <strong>5:42 am</strong>, Sunset: <strong>6:27 pm</strong></div><div><a href="city?id=31">Read More...</a></div></div></div></div></div></div><div class="item"><img data-src="holder.js/749x500/audo/#666:#6a6a/text:SomeText" src="/mfd.gov.np/_files/8e9309b9514a49e5b0d09ab5139fe108.jpg"/><div class="container"><div class="carousel-caption"><div class="st ...
#  	<div class="container">
#  		<div class="row">
#  			<div class="col-sm-6">
#  				<h3>Contact Us</h3>
#  				<h4>Meteorological Forecasting Division</h4>
#  				<p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>
#  				<p><b>Please dial and listen to us for notice board service</b>
#  				</p><dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>
#  			</div>
#  			<div class="col-sm-6">
#  				<h3>Links</h3>
#  				<h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>
#
#  				<h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>
#  				<h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>
#  			</div>
#  		</div>
#  	</div>
#  <iframe src="http://dhm.gov.np/commonfooter.php" style="width:100%; border:none"></iframe>
#
#
#  </footer>, <div class="container">
#  		<div class="row">
#  			<div class="col-sm-6">
#  				<h3>Contact Us</h3>
#  				<h4>Meteorological Forecasting Division</h4>
#  				<p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>
#  				<p><b>Please dial and listen to us for notice board service</b>
#  				</p><dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>
#  			</div>
#  			<div class="col-sm-6">
#  				<h3>Links</h3>
#  				<h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>
#
#  				<h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>
#  				<h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>
#  			</div>
#  		</div>
#  	</div>, <div class="row">
#  			<div class="col-sm-6">
#  				<h3>Contact Us</h3>
#  				<h4>Meteorological Forecasting Division</h4>
#  				<p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>
#  				<p><b>Please dial and listen to us for notice board service</b>
#  				</p><dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>
#  			</div>
#  			<div class="col-sm-6">
#  				<h3>Links</h3>
#  				<h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>
#
#  				<h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>
#  				<h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>
#  			</div>
#  		</div>, <div class="col-sm-6">
#  				<h3>Contact Us</h3>
#  				<h4>Meteorological Forecasting Division</h4>
#  				<p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>
#  				<p><b>Please dial and listen to us for notice board service</b>
#  				</p><dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>
#  			</div>, <h3>Contact Us</h3>, <h4>Meteorological Forecasting Division</h4>, <p>Gauchar, Tribhuvan International Airport<br/>
#  					Kathmandu, Nepal<br/>
#  					<abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>:
#  					+977 1 4486869<br/>
#  					<abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>:
#  					<a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>
#  				</p>, <br/>, <br/>, <abbr title="Phone"><span class="glyphicon glyphicon-earphone"></span></abbr>, <span class="glyphicon glyphicon-earphone"></span>, <br/>, <abbr title="Email"><span class="glyphicon glyphicon-envelope"></span></abbr>, <span class="glyphicon glyphicon-envelope"></span>, <a href="mailto:info@mfd.gov.np">info@mfd.gov.np</a>, <p><b>Please dial and listen to us for notice board service</b>
#  				</p>, <b>Please dial and listen to us for notice board service</b>, <dl class="footer-number-list dl-horizontal">
#  					<dt>Kathmandu:</dt><dd>1618 07 07 33333 (for daily weather updates)</dd>
#  					<dt>Surkhet:</dt><dd>1618 083 523519 (for daily weather data)</dd>
#  					<dt>Pokhara:</dt><dd>1618 061 465299 (for daily weather data)</dd>
#  					<dt>Dharan:</dt><dd>1618 025 520272 (for daily weather data)</dd>
#  				</dl>, <dt>Kathmandu:</dt>, <dd>1618 07 07 33333 (for daily weather updates)</dd>, <dt>Surkhet:</dt>, <dd>1618 083 523519 (for daily weather data)</dd>, <dt>Pokhara:</dt>, <dd>1618 061 465299 (for daily weather data)</dd>, <dt>Dharan:</dt>, <dd>1618 025 520272 (for daily weather data)</dd>, <div class="col-sm-6">
#  				<h3>Links</h3>
#  				<h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>
#
#  				<h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>
#  				<h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>
#  			</div>, <h3>Links</h3>, <h4>
#  					<a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>
#  				</h4>, <a href="http://www.dhm.gov.np" target="_blank">Department of Hydrology and
#  						Meteorology</a>, <h4>
#  					<a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>
#  				</h4>, <a href="http://www.hydrology.gov.np" target="_blank">Flood        Forecasting Division</a>, <h4>
#  					<a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>
#  				</h4>, <a href="http://www.mope.gov.np" target="_blank">Ministry of Population and Environment</a>, <iframe src="http://dhm.gov.np/commonfooter.php" style="width:100%; border:none"></iframe>, <div class="copyright-line">
#  	<div class="container">
#
#  		<div class="row">
#
#  			<div class="col-sm-6">
#
#  				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
#  			</div>
#
#  			<div class="col-sm-6">
#
#  				<p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>
#  			</div>
#  		</div>
#  	</div>
#  </div>, <div class="container">
#
#  		<div class="row">
#
#  			<div class="col-sm-6">
#
#  				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
#  			</div>
#
#  			<div class="col-sm-6">
#
#  				<p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>
#  			</div>
#  		</div>
#  	</div>, <div class="row">
#
#  			<div class="col-sm-6">
#
#  				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
#  			</div>
#
#  			<div class="col-sm-6">
#
#  				<p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>
#  			</div>
#  		</div>, <div class="col-sm-6">
#
#  				<p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>
#  			</div>, <p><small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small></p>, <small>Copyright © 2017 Meteorological Forecasting Divison, DHM</small>, <div class="col-sm-6">
#
#  				<p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>
#  			</div>, <p><small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>
#  				</p>, <small>
#
#  						Designed and developed by <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a></small>, <a href="http://www.rts.com.np">Real
#
#  							Time Solutions Pvt. Ltd.</a>, <script src="/mfd.gov.np/_jquery/jquery-1.11.0.min.js"></script>, <script src="/mfd.gov.np/_bootstrap/js/bootstrap.min.js"></script>, <script src="/mfd.gov.np/_js/highstock.js"></script>, <script> $('li').tooltip(); </script>, <script>
#  	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#  	ga('create', 'UA-48154100-1', 'www.mfd.gov.np');
#  	ga('send', 'pageview');
#
#  </script>]

# %%
maindiv = soup.find('div', attrs={'class': 'weather-data-table'})

# %%
maindiv.find('table')
# Out:
# <table class="table" style="margin-bottom: 0px"><tbody><tr><th>Station</th><th class="center">Maximum Temp.<br/>(°C)</th><th class="center">Minimum Temp.<br/>(°C)</th><th class="center">24 hrs Rainfall<br/>(mm)</th></tr><tr><td>Dipayal</td><td class="center">35.8</td><td class="center">23.0</td><td class="center">0.0</td></tr><tr><td>Dadeldhura</td><td class="center">26.0</td><td class="center">17.6</td><td class="center">6.8</td></tr><tr><td>Dhangadi</td><td class="center">35.0</td><td class="center">26.2</td><td class="center">0.0</td></tr><tr><td>Birendranagar</td><td class="center">32.7</td><td class="center">22.8</td><td class="center">0.0</td></tr><tr><td>Nepalgunj</td><td class="center">34.6</td><td class="center">25.2</td><td class="center">0.0</td></tr><tr><td>Jumla</td><td class="center">25.3</td><td class="center">15.8</td><td class="center">13.9</td></tr><tr><td>Dang</td><td class="center">31.3</td><td class="center">23.5</td><td class="center">0.6</td></tr><tr><td>Pokhara</td><td class="center">32.3</td><td class="center">23.5</td><td class="center">0.0</td></tr><tr><td>Bhairahawa</td><td class="center">-</td><td class="center">27.0</td><td class="center">-</td></tr><tr><td>Simara</td><td class="center">34.0</td><td class="center">26.8</td><td class="center">0.0</td></tr><tr><td>Kathmandu</td><td class="center">29.5</td><td class="center">19.4</td><td class="center">0.0</td></tr><tr><td>Okhaldhunga</td><td class="center">25.7</td><td class="center">17.0</td><td class="center">0.0</td></tr><tr><td>Taplejung</td><td class="center">27.4</td><td class="center">18.6</td><td class="center">0.0</td></tr><tr><td>Dhankuta</td><td class="center">28.4</td><td class="center">19.9</td><td class="center">2.1</td></tr><tr><td>Biratnagar</td><td class="center">34.5</td><td class="center">26.2</td><td class="center">0.0</td></tr><tr><td>Jomsom</td><td class="center">22.0</td><td class="center">13.0</td><td class="center">5.5*</td></tr><tr><td>Dharan</td><td class="center">33.5</td><td class="center">24.5</td><td class="center">14.4*</td></tr><tr><td>Lumle</td><td class="center">24.0</td><td class="center">18.1</td><td class="center">3.5*</td></tr><tr><td>Jankapur</td><td class="center">34.2</td><td class="center">27.2</td><td class="center">Traces*</td></tr><tr><td>Jiri</td><td class="center">24.4</td><td class="center">16.1</td><td class="center">2.3*</td></tr><tr><td align="right" colspan="4"><small>* Daily rainfall data ending at 08:45 AM NPT</small></td></tr></tbody></table>

# %%
maindiv.find('table').find('tbody').find_all('tr')
# Out:
# [<tr><th>Station</th><th class="center dark">Maximum Temp.*<br/>(°C)</th><th class="center">Minimum Temp.<br/>(°C)</th><th class="center">24 hrs Rainfall<br/>(mm)</th></tr>,
#  <tr><td>Dipayal</td><td class="center dark">30.0</td><td class="center">24.8</td><td class="center">3.0</td></tr>,
#  <tr><td>Dadeldhura</td><td class="center dark">24.4</td><td class="center">17.1</td><td class="center">10.0</td></tr>,
#  <tr><td>Dhangadi</td><td class="center dark">31.9</td><td class="center">24.9</td><td class="center">18.0</td></tr>,
#  <tr><td>Birendranagar</td><td class="center dark">31.2</td><td class="center">22.8</td><td class="center">0.3</td></tr>,
#  <tr><td>Nepalgunj</td><td class="center dark">32.5</td><td class="center">25.2</td><td class="center">13.0</td></tr>,
#  <tr><td>Jumla</td><td class="center dark">24.5</td><td class="center">15.5</td><td class="center">12.0</td></tr>,
#  <tr><td>Dang</td><td class="center dark">30.2</td><td class="center">23.2</td><td class="center">72.0</td></tr>,
#  <tr><td>Pokhara</td><td class="center dark">31.5</td><td class="center">21.4</td><td class="center">22.0</td></tr>,
#  <tr><td>Bhairahawa</td><td class="center dark">34.5</td><td class="center">25.8</td><td class="center">21.0</td></tr>,
#  <tr><td>Simara</td><td class="center dark">33.0</td><td class="center">25.2</td><td class="center">0.0</td></tr>,
#  <tr><td>Kathmandu</td><td class="center dark">29.4</td><td class="center">20.5</td><td class="center">7.0</td></tr>,
#  <tr><td>Okhaldhunga</td><td class="center dark">23.3</td><td class="center">17.5</td><td class="center">12.0</td></tr>,
#  <tr><td>Taplejung</td><td class="center dark">23.7</td><td class="center">18.3</td><td class="center">3.0</td></tr>,
#  <tr><td>Dhankuta</td><td class="center dark">24.5</td><td class="center">20.9</td><td class="center">5.0</td></tr>,
#  <tr><td>Biratnagar</td><td class="center dark">28.8</td><td class="center">26.3</td><td class="center">3.0</td></tr>,
#  <tr><td align="right" colspan="4"><small>* The maximum temp. as recorded yesterday afternoon</small></td></tr>]

# %%
for row in maindiv.find('table').find('tbody').find_all('tr'):
    if row.find('th'):
        continue
    tds = row.find_all('td')
    print(tds)
    print("Station", tds[0].text)
    print("Maximum", tds[1].text)
    print("Minimum", tds[2].text)
    print("Rainfall", tds[3].text)
    break
# Out:
# [<td>Dipayal</td>, <td class="center dark">30.0</td>, <td class="center">24.8</td>, <td class="center">3.0</td>]
# Station Dipayal
# Maximum 30.0
# Minimum 24.8
# Rainfall 3.0

# %%
with open('../Data/sample.csv', 'w') as csvfile:
    csvwriter = csv.DictWriter(csvfile, 
                               fieldnames=['Station', 'Maximum', 'Minimum', 'Rainfall'])
    csvwriter.writeheader()
    
    data = []
    for row in maindiv.find('table').find('tbody').find_all('tr'):
        _rowdata = {}
        if row.find('th'):
            continue
        tds = row.find_all('td')
        _rowdata["Maximum"] = tds[1].text.strip()
        _rowdata["Minimum"] = tds[2].text.strip()
        _rowdata["Rainfall"] = tds[3].text.strip()
        _rowdata["Station"] = tds[0].text.strip()
        data.append(_rowdata)
    csvwriter.writerows(data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-c2d6953428fc> in <module>()
#      10             continue
#      11         tds = row.find_all('td')
# ---> 12         _rowdata["Maximum"] = tds[1].text.strip()
#      13         _rowdata["Minimum"] = tds[2].text.strip()
#      14         _rowdata["Rainfall"] = tds[3].text.strip()
#
# IndexError: list index out of range
